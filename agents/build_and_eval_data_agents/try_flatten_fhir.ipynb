# %% [markdown]
# Using data generated from Synthea, I want to try out the `fhirpower` from fhirfly.

# %%
# %pip install fhirpower --user
# Out:
# Collecting fhirpower
#   Downloading fhirpower-0.1.0-py3-none-any.whl.metadata (3.1 kB)
# Downloading fhirpower-0.1.0-py3-none-any.whl (2.7 kB)
# Installing collected packages: fhirpower
# Successfully installed fhirpower-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from fhirpower import flatten_fhir
import json

# %%
with open('./fhir/Aaron697_Brekke496_2fa15bc7-8866-461a-9000-f739e425860a.json') as f:
    source_json = json.load(f)

flattened_json = flatten_fhir(source_json)
print(flattened_json)
# Out:
# {'resourceType': 'Bundle', 'type': 'transaction', 'entry_0_fullUrl': 'urn:uuid:5cbc121b-cd71-4428-b8b7-31e53eba8184', 'entry_0_resource_resourceType': 'Patient', 'entry_0_resource_id': '5cbc121b-cd71-4428-b8b7-31e53eba8184', 'entry_0_resource_text_status': 'generated', 'entry_0_resource_text_div': '<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: v2.4.0-404-ge7ce2295\n .   Person seed: 6457100290386878904  Population seed: 0</div>', 'entry_0_resource_extension_0_url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-race', 'entry_0_resource_extension_0_extension_0_url': 'ombCategory', 'entry_0_resource_extension_0_extension_0_valueCoding_system': 'urn:oid:2.16.840.1.113883.6.238', 'entry_0_resource_extension_0_extension_0_valueCoding_code': '2106-3', 'entry_0_resource_extension_0_extension_0_valueCoding_display': 'White', 'entry_0_resource_extension_0_extension_1_url': 'text', 'entry_0_resource_extension_0_extension_1_valueString': 'White', 'entry_0_resource_extension_1_url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-ethnicity', 'entry_0_resource_extension_1_extension_0_url': 'ombCategory', 'entry_0_resource_extension_1_extension_0_valueCoding_system': 'urn:oid:2.16.840.1.113883.6.238', 'entry_0_resource_extension_1_extension_0_valueCoding_code': '2186-5', 'entry_0_resource_extension_1_extension_0_valueCoding_display': 'Not Hispanic or Latino', 'entry_0_resource_extension_1_extension_1_url': 'text', 'entry_0_resource_extension_1_extension_1_valueString': 'Not Hispanic or Latino', 'entry_0_resource_extension_2_url': 'http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName', 'entry_0_resource_extension_2_valueString': 'Deadra347 Borer986', 'entry_0_resource_extension_3_url': 'http://hl7.org/fhir/us/core/StructureDefinition/us-core-birthsex', 'entry_0_resource_extension_3_valueCode': 'M', 'entry_0_resource_extension_4_url': 'http://hl7.org/fhir/StructureDefinition/patient-birthPlace', 'entry_0_resource_extension_4_valueAddress_city': 'Billerica', 'entry_0_resource_extension_4_valueAddress_state': 'Massachusetts', 'entry_0_resource_extension_4_valueAddress_country': 'US', 'entry_0_resource_extension_5_url': 'http://synthetichealth.github.io/synthea/disability-adjusted-life-years', 'entry_0_resource_extension_5_valueDecimal': 14.062655945052095, 'entry_0_resource_extension_6_url': 'http://synthetichealth.github.io/synthea/quality-adjusted-life-years', 'entry_0_resource_extension_6_valueDecimal': 58.93734405494791, 'entry_0_resource_identifier_0_system': 'https://github.com/synthetichealth/synthea', 'entry_0_resource_identifier_0_value': '2fa15bc7-8866-461a-9000-f739e425860a', 'entry_0_resource_identifier_1_type_coding_0_system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'entry_0_resource_identifier_1_type_coding_0_code': 'MR', 'entry_0_resource_identifier_1_type_coding_0_display': 'Medical Record Number', 'entry_0_resource_identifier_1_type_text': 'Medical Record Number', 'entry_0_resource_identifier_1_system': 'http://hospital.smarthealthit.org', 'entry_0_resource_identifier_1_value': '2fa15bc7-8866-461a-9000-f739e425860a', 'entry_0_resource_identifier_2_type_coding_0_system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'entry_0_resource_identifier_2_type_coding_0_code': 'SS', 'entry_0_resource_identifier_2_type_coding_0_display': 'Social Security Number', 'entry_0_resource_identifier_2_type_text': 'Social Security Number', 'entry_0_resource_identifier_2_system': 'http://hl7.org/fhir/sid/us-ssn', 'entry_0_resource_identifier_2_value': '999-93-7537', 'entry_0_resource_identifier_3_type_coding_0_system': 'http://terminology.hl7.org/CodeSystem/v2-0203', 'entry_0_resource_identifier_3_type_coding_0_code': 'DL', 'entry_0_resource_identifier_3_type_coding_0_display': "Driver's License", 'entry_0_resource_identifier_3_type_text': "Driver's License", 'entry_0_resource_identifier_3_system': 'urn:oid:2.16.8 ...
